# %% [markdown]
# # <center>实验8 聚类分析</center>

# %% [markdown]
# <B>1. 基本概念</B>
#
# K-means算法是一种基于距离的聚类算法。
#
# 采用距离作为相似性的评价指标，即认为两个对象的距离越近，其相似度就越大。
#
# 该算法认为类簇是由距离靠近的对象组成的，因此把得到紧凑且独立的簇作为最终目标.

# %% [markdown]
# <B>2. 核心思想</B>
#
# 通过迭代寻找$K$个簇的一种划分方案，使得用这$K$个簇的均值来代表相应各类样本时所得的总体误差最小。
#
# $K$个簇具有以下特点:各簇本身尽可能的紧凑，而各簇之间尽可能的分开。
#
# K-means算法的基础是最小误差平方和准则，其目标函数是:
#
# <center> $SSE= \sum_{i=1}^{k} \sum_{x \in C_i} dist(c_i,x)^2$ </center>
#
# 各簇内的样本越相似，其与该类均值间的误差平方越小，对所有类所得到的误差平方求和，即可验证分为$K$类时，各簇是否是最优的。

# %% [markdown]
# <B>3. 质心初始化</B>
#
# K-means++通过一种更合理的方式来选择初始聚类中心，使得算法更有可能找到全局最优解，而不是陷入局部最优。
#
# 在K-means++中，对于每一个未被选作聚类中心的点 $x$，计算其到最近的聚类中心的距离 $D$($x$)，通常是欧氏距离。
#
# 选择下一个聚类中心的概率与距离平方成正比：
#
# <center> $P(x)= \frac{D(x)^2}{\sum_{x \in X}D(x)^2}$ </center>
#
# 分母是指对数据集$X$中的所有点$x$的距离平方$D(x)^2$求和
#
# 这意味着，如果一个点$x$到最近的聚类中心的距离较大，那么它被选为下一个聚类中心的概率也较高。

# %% [markdown]
# <B>4. 数据集</B>
#
# 本实验采用二维数据集，共80个样本，部分数据如下：
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from numpy import *

# %%
# 加载并输出数据
def loadDataSet(fileName):
    data = np.loadtxt(fileName, delimiter='\t')
    return data
data = loadDataSet('dataSet.txt')
x = data[:,0]
y = data[:,1]

print(data[:10])  #输出前10个
# Out:
# [[ 1.658985  4.285136]
#  [-3.453687  3.424321]
#  [ 4.838138 -1.151539]
#  [-5.379713 -3.362104]
#  [ 0.972564  2.924086]
#  [-3.567919  1.531611]
#  [ 0.450614 -3.302219]
#  [-3.487105 -1.724432]
#  [ 2.668759  1.594842]
#  [-3.156485  3.191137]]

# %%
# 对数据进行可视化
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.title('Original data')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y,alpha=0.5,c='blue', label='Data Points')
plt.grid(True)

# %%
# 计算欧氏距离
def distEclid(vecA, vecB):
    return sqrt(sum(power(vecA - vecB, 2)))    #计算两个对象之间的距离

# %%
#1. 随机选取k个质心，返回的数组中保存有初始质心的坐标
def randCent(dataSet, k):
    n = np.shape(dataSet)[1]
    centroids = np.zeros((k, n))  # 总共k个质心，每个质心有n个坐标值
 
    #补充你的代码
    for i in range(n):
        minVal = np.min(dataSet[:, i])  # 获取第i列的最小值
        maxVal = np.max(dataSet[:, i])  # 获取第i列的最大值
        rangeVal = maxVal - minVal  # 计算范围
        centroids[:, i] = minVal + rangeVal * np.random.rand(k)  # 在范围内随机生成k个值

    return centroids

#输出4个随机初始质心
centroids = randCent(data, 4) 
print("Initial random centroids:\n", centroids)
# Out:
# Initial random centroids:
#  [[-2.78886026 -0.48414625]
#  [ 4.78429575 -1.90784826]
#  [-2.67810962 -3.66713508]
#  [-2.39165597  0.65285868]]

# %%
# 对随机初始质心进行可视化
plt.figure(figsize=(8, 6))
plt.title('Original data and random centers')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y,alpha=0.5,c='blue', label='Data Points')
plt.scatter(centroids[:,0], centroids[:,1], color='r',s=150,marker='+',label='Centers')
plt.legend()
plt.grid(True)

# %%
# 使用𝐾-means++初始化质心
def initialize_centers(X, k, seed=50):
    if seed is not None:
        np.random.seed(seed)  # 设置随机种子，保证随机性一致
    
    centers = [X[np.random.randint(X.shape[0])]]  # 随机选择第一个中心
    while len(centers) < k:
        # 计算到最近中心的平方距离
        dist_sq = []
        for x in X:
            min_dist = min([np.linalg.norm(x - c)**2 for c in centers])
            dist_sq.append(min_dist)
        dist_sq = np.array(dist_sq)
        probs = dist_sq / dist_sq.sum()  # 计算概率
        cumulative_probs = probs.cumsum()
        r = np.random.rand()
        # 按累计概率选择下一个中心
        for j, p in enumerate(cumulative_probs):
            if r < p:
                centers.append(X[j])
                break
    return np.vstack(centers)

k = 4  # 设定中心点数量
createCent = initialize_centers(data, k)
print("Created centroids:\n", createCent)
# Out:
# Created centroids:
#  [[ 3.542056  2.778832]
#  [-3.156485  3.191137]
#  [ 0.450614 -3.302219]
#  [-4.323818 -3.938116]]

# %%
# 对创建的初始质心进行可视化
plt.figure(figsize=(8, 6))
plt.title('Original data and created centers')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y,alpha=0.5,c='blue', label='Data Points')
plt.scatter(createCent[:,0], createCent[:,1], color='g',s=150,marker='+',label='Centers')
plt.legend()
plt.grid(True)

# %%
#2. k-means 聚类算法
def kMeans(dataSet, k, distMeans=distEclid, createCent=randCent):
    m, n = dataSet.shape
    clusterAssment = np.zeros((m, 2))   # 用于存放该样本属于哪簇及到质心距离
    centroids = createCent(dataSet, k)  # 质心初始化

    #补充你的代码
    clusterChanged = True  # 标记簇是否发生变化
    maxIter = 300  # 最大迭代次数
    
    while clusterChanged and maxIter > 0:
        clusterChanged = False
        maxIter -= 1
        
        # 将每个样本分配到最近的质心
        for i in range(m):
            minDist = np.inf  # 最小距离初始化为无穷大
            minIndex = -1  # 最近的簇索引
            
            # 计算样本到每个质心的距离，找到最近的质心
            for j in range(k):
                distJI = distMeans(centroids[j], dataSet[i])
                if distJI < minDist:
                    minDist = distJI
                    minIndex = j
            
            # 如果样本的簇分配发生变化，标记clusterChanged为True
            if clusterAssment[i, 0] != minIndex:
                clusterChanged = True
            
            # 更新样本的簇分配和距离
            clusterAssment[i, :] = minIndex, minDist**2
        
        # 更新每个簇的质心
        for cent in range(k):
            # 获取属于当前簇的所有样本
            ptsInClust = dataSet[clusterAssment[:, 0] == cent]
            if len(ptsInClust) > 0:
                # 计算簇内所有样本的均值作为新的质心
                centroids[cent, :] = np.mean(ptsInClust, axis=0)
    
    return centroids, clusterAssment

#输出聚类结果
centroids, clusterAssment = kMeans(data, 4, distEclid, initialize_centers) 
print("Final centroids:\n", centroids)  #最终的聚类中心
print("Cluster assignment:\n", clusterAssment)  #每个样本被分配的簇标号，以及到聚类中心的距离
# Out:
# Final centroids:
#  [[ 2.6265303   3.10868015]
#  [-2.46154315  2.78737555]
#  [ 2.65077367 -2.79057124]
#  [-3.53973889 -2.89384326]]
# Cluster assignment:
#  [[ 0.          2.32019227]
#  [ 1.          1.39004893]
#  [ 2.          7.4709894 ]
#  [ 3.          3.60477283]
#  [ 0.          2.76967952]
#  [ 1.          2.80101213]
#  [ 2.          5.10248599]
#  [ 3.          1.37029303]
#  [ 0.          2.29348921]
#  [ 1.          0.64596748]
#  [ 2.          1.72727548]
#  [ 3.          0.60909593]
#  [ 0.          2.51695276]
#  [ 1.          0.13871642]
#  [ 2.          9.13029102]
#  [ 2.         10.63696385]
#  [ 0.          2.39726898]
#  [ 1.          3.1024236 ]
#  [ 2.          0.40661288]
#  [ 3.          0.49023594]
#  [ 0.          0.13870636]
#  [ 1.          0.510241  ]
#  [ 2.          0.9946502 ]
#  [ 3.          0.03195031]
#  [ 0.          1.31601173]
#  [ 1.          0.90820377]
#  [ 2.          0.54533578]
#  [ 3.          0.31668166]
#  [ 0.          0.21378691]
#  [ 1.          4.05632356]
#  [ 2.          4.44868518]
#  [ 3.          0.41852436]
#  [ 0.          0.4761432 ]
#  [ 1.          1.5441411 ]
#  [ 2.          6.8391407 ]
#  [ 3.          1.28690535]
#  [ 0.          4.87745833]
#  [ 1.          3.12703929]
#  [ 2.          0.05192972]
#  [ 3.          0.21846598]
#  [ 0.          0.88495612]
#  [ 1.          0.0798871 ]
#  [ 2.          0.66844081]
#  [ 3.          3.80369324]
#  [ 0.          0.09325259]
#  [ 1.          0.91370546]
#  [ 2.          1.24409358]
#  [ 3.          0.26256416]
#  [ 0.          0.94698711]
#  [ 1.          2.63836399]
#  [ 2.          0.31155338]
#  [ 3.          1.70528559]
#  [ 0.          5.46768683]
#  [ 1.          5.73153563]
#  [ 2.          0.22174766]
#  [ 3.          0.22758842]
#  [ 0.          1.32864705]
#  [ 1.          0.02380325]
#  [ 2.          0.76721648]
#  [ 3.          0.59634253]
#  [ 0.          0.45550693]
#  [ 1.          0.01962128]
#  [ 2.          2.04456545]
#  [ 3.          1.72614177]
#  [ 0.          1.26363954]
#  [ 1.          1.33108375]
#  [ 2.          0.19043724]
#  [ 3.          0.83327924]
#  [ 0.          0.09525188]
#  [ 1.          0.62512976]
#  [ 2.          0.84629025]
#  [ 3.          1.62463639]
#  [ 0.          6.39227166]
#  [ 1.          0.20120037]
#  [ 2.          4.12472463]
#  [ 3.          1.11099937]
#  [ 0.          0.07060126]
#  [ 1.          0.2599013 ]
#  [ 2.          4.39588966]
#  [ 3.          1.86578044]]

# %%
# 对聚类结果进行可视化
plt.figure(figsize=(8, 6))
plt.title('Clustering results and final centers')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y,alpha=0.5,c=clusterAssment[:,0], label='Data Points')
plt.scatter(centroids[:,0], centroids[:,1], color='r',s=150,marker='+',label='Centers')
plt.legend()
plt.grid(True)

# %%
# 计算轮廓系数指标
from sklearn.metrics import silhouette_score
score = silhouette_score(data, clusterAssment[:,0] , metric='euclidean')
score
# Out:
# np.float64(0.6566268049712372)
